# %%
import pandas as pd

note_path = "/data1/project/juhyeon/MAGNET/OSS/mimic-iii-10k/NOTEEVENTS/NOTEEVENTS_sorted.csv"
adm_path  = "/data1/project/juhyeon/MAGNET/OSS/mimic-iii-10k/ADMISSIONS/ADMISSIONS_sorted.csv"
icu_path  = "/data1/project/juhyeon/MAGNET/OSS/mimic-iii-10k/ICUSTAYS/ICUSTAYS_sorted.csv"

notes_raw = pd.read_csv(
    note_path,
    parse_dates=["CHARTDATE", "CHARTTIME"],  # STORETIME 없으면 생략
    low_memory=False
)

adm_raw = pd.read_csv(
    adm_path,
    parse_dates=["ADMITTIME", "DISCHTIME"],  # DEATHTIME, EDREGTIME 등 없는 경우 생략
    low_memory=False
)

icu_raw = pd.read_csv(
    icu_path,
    parse_dates=["INTIME", "OUTTIME"],
    low_memory=False
)


#    adm  -> SUBJECT_ID, HADM_ID, ADMITTIME, DEATHTIME, HOSPITAL_EXPIRE_FLAG
#    notes-> SUBJECT_ID, HADM_ID, CHARTTIME, CATEGORY, ISERROR, TEXT
#    icu  -> SUBJECT_ID, HADM_ID, ICUSTAY_ID, INTIME, OUTTIME

# ADMISSIONS 쪽: DEATHTIME이 없을 수도 있으므로 없으면 만들고 진행
adm_cols = ["SUBJECT_ID", "HADM_ID", "ADMITTIME", "HOSPITAL_EXPIRE_FLAG"]
if "DEATHTIME" in adm_raw.columns:
    adm_cols.append("DEATHTIME")
admissions = adm_raw[adm_cols].copy()

# NOTEEVENTS 쪽: ISERROR 컬럼이 있는지 확인해서 없으면 0으로 채운다
note_cols = ["SUBJECT_ID", "HADM_ID", "CHARTTIME", "CATEGORY", "TEXT"]
if "ISERROR" in notes_raw.columns:
    note_cols.insert(4, "ISERROR")  # TEXT는 맨 끝으로 가도록
notes = notes_raw[note_cols].copy()

# ICUSTAYS 쪽
icu_cols = ["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID", "INTIME", "OUTTIME"]
icustays = icu_raw[icu_cols].copy()

# 노트 전처리 
#    - ISERROR == 1 인 노트 제거
#    - TEXT NaN -> "" 후 공백 압축 & strip
if "ISERROR" in notes.columns:
    notes = notes[notes["ISERROR"].fillna(0) != 1]

notes["TEXT"] = (
    notes["TEXT"]
    .fillna("")
    .str.replace(r"\s+", " ", regex=True)
    .str.strip())


# HADM_ID 결측 제거 (ICU/ADM과 붙이려면 필요)
notes = notes.dropna(subset=["HADM_ID"]).copy()
notes["HADM_ID"] = notes["HADM_ID"].astype("int64", errors="ignore")

admissions = admissions.dropna(subset=["HADM_ID"]).copy()
admissions["HADM_ID"] = admissions["HADM_ID"].astype("int64", errors="ignore")

icustays = icustays.dropna(subset=["HADM_ID"]).copy()
icustays["HADM_ID"] = icustays["HADM_ID"].astype("int64", errors="ignore")


# ICU 입실 시간 정리 (src 스타일)
#    동일 (SUBJECT_ID, HADM_ID) 조합에 대해 INTIME이 가장 이른 ICU stay만 남김
icustays = (
    icustays
    .sort_values("INTIME")
    .drop_duplicates(subset=["SUBJECT_ID", "HADM_ID"], keep="first")
    .copy())

# 병합: notes + admissions + icu
df = (
    notes
    .merge(admissions, on=["SUBJECT_ID", "HADM_ID"], how="inner")
    .merge(icustays,  on=["SUBJECT_ID", "HADM_ID"], how="inner"))

# ICU 입실 시간 기준 48시간 윈도우 필터
#    INTIME ≤ CHARTTIME ≤ INTIME + 48h
df = df.dropna(subset=["INTIME", "CHARTTIME"]).copy()

time_mask = (
    (df["CHARTTIME"] >= df["INTIME"]) &
    (df["CHARTTIME"] <= df["INTIME"] + pd.Timedelta(hours=48)))
df = df[time_mask].copy()


# 라벨 생성 HOSPITAL_EXPIRE_FLAG -> label (int)
df["label"] = df["HOSPITAL_EXPIRE_FLAG"].fillna(0).astype(int)

# ICU 기준 경과 시간(Hours) 계산
# Hours = (CHARTTIME - INTIME) [hr]
df["Hours"] = (df["CHARTTIME"] - df["INTIME"]).dt.total_seconds() / 3600.0


final_dataset = df[[
    "SUBJECT_ID",
    "HADM_ID",
    "ICUSTAY_ID",
    "CATEGORY",
    "TEXT",
    "CHARTTIME",
    "INTIME",
    "Hours",
    "label",
    "HOSPITAL_EXPIRE_FLAG"]].copy()

print("=== 최종 데이터셋 샘플 ===")
print(final_dataset.head(3))
print(f"\n최종 행 수(=ICU 입실 후 48h 노트 수): {len(final_dataset):,}")

print("\n라벨 분포:")
print((final_dataset["label"].value_counts(normalize=True) * 100).round(2))
# Out:
# === 최종 데이터셋 샘플 ===
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID       CATEGORY  \
# 0           2   163353      243653  Nursing/other
# 1           2   163353      243653  Nursing/other
# 5           3   145834      211552  Nursing/other
#
#                                                 TEXT           CHARTTIME  \
# 0  Neonatology Attending Triage Note Baby [**Name... 2138-07-17 22:51:00
# 1  Nursing Transfer note Pt admitted to NICU for ... 2138-07-17 23:08:00
# 5  Micu Progress Nursing Note: Patient arrived in... 2101-10-21 06:58:00
#
#                INTIME      Hours  label  HOSPITAL_EXPIRE_FLAG
# 0 2138-07-17 21:20:07   1.514722      0                     0
# 1 2138-07-17 21:20:07   1.798056      0                     0
# 5 2101-10-20 19:10:11  11.796944      0                     0
#
# 최종 행 수(=ICU 입실 후 48h 노트 수): 93,781
#
# 라벨 분포:
# label
# 0    88.32
# 1    11.68
# Name: proportion, dtype: float64

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93781 entries, 0 to 430964
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SUBJECT_ID            93781 non-null  int64
#  1   HADM_ID               93781 non-null  int64
#  2   ICUSTAY_ID            93781 non-null  int64
#  3   CATEGORY              93781 non-null  object
#  4   TEXT                  93781 non-null  object
#  5   CHARTTIME             93781 non-null  datetime64[ns]
#  6   INTIME                93781 non-null  datetime64[ns]
#  7   Hours                 93781 non-null  float64
#  8   label                 93781 non-null  int64
#  9   HOSPITAL_EXPIRE_FLAG  93781 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(5), object(2)
# memory usage: 7.9+ MB

# %%
# import os
# import glob

# # 대상 폴더 경로
# folder_path = "/data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note"

# # 폴더 안의 모든 .csv 파일 경로 리스트
# csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# # 파일 삭제
# for file_path in csv_files:
#     try:
#         os.remove(file_path)
#         print(f"Deleted: {file_path}")
#     except Exception as e:
#         print(f"Error deleting {file_path}: {e}")

# print("✅ 모든 .csv 파일 삭제 완료")
# Out:
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6454_episode971.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9220_episode2121.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7092_episode1770.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2074_episode1486.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4329_episode2224.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4419_episode1282.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1863_episode2101.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/668_episode1629.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/484_episode594.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4163_episode915.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3707_episode585.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4375_episode1661.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2266_episode876.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5175_episode188.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9067_episode137.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/646_episode577.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7475_episode472.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9352_episode1666.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7993_episode2097.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/871_episode1009.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5142_episode785.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6374_episode532.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4389_episode1455.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8701_episode451.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2675_episode1466.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1711_episode790.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4711_episode2456.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/229_episode2126.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3910_episode150.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9650_episode123.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6430_episode22.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5866_episode1475.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7124_episode226.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7995_episode2251.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9519_episode1489.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5011_episode713.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8167_episode442.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6849_episode583.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7296_episode1071.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4113_episode2037.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3202_episode1996.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8344_episode2360.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9290_episode801.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3214_episode506.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1988_episode922.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3287_episode273.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8104_episode1625.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5588_episode1264.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2647_episode679.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5244_episode1290.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7747_episode2086.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6832_episode1575.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9645_episode131.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7884_episode2391.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6027_episode2012.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3703_episode2111.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3140_episode541.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8095_episode1766.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6904_episode2106.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2399_episode1413.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5882_episode2102.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10365_episode1958.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/665_episode1272.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8110_episode1966.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9417_episode2239.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4623_episode1777.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1651_episode810.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2794_episode1824.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/297_episode181.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1456_episode1321.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1076_episode1733.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10394_episode2022.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8397_episode575.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8569_episode702.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9322_episode1586.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1031_episode1584.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8409_episode1411.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2963_episode1018.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7726_episode2041.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8620_episode1189.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7060_episode561.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9992_episode377.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9301_episode1795.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10230_episode198.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3036_episode1042.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1697_episode11.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8678_episode1129.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7899_episode43.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5052_episode1713.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5013_episode579.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9105_episode77.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7477_episode2213.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/947_episode1011.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7797_episode2114.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7785_episode1197.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8456_episode1568.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5262_episode2307.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7202_episode1128.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1292_episode1248.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3100_episode1191.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4104_episode1463.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/239_episode685.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2212_episode1621.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10387_episode1924.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8792_episode1316.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3844_episode544.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8309_episode870.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8503_episode2043.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2635_episode1715.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9066_episode2048.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9465_episode722.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/761_episode1557.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8803_episode2454.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3906_episode1619.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5782_episode1496.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1807_episode1918.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1577_episode2225.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10471_episode1369.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3418_episode2166.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4961_episode1367.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5140_episode2289.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1000_episode1048.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3554_episode1225.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5617_episode1806.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9959_episode333.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1226_episode93.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8770_episode13.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2790_episode1102.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3153_episode1797.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9010_episode731.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5142_episode463.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7543_episode1565.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2625_episode1077.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4713_episode1642.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6642_episode390.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3230_episode553.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1611_episode1690.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4232_episode1634.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/360_episode1330.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4094_episode558.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3285_episode686.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3897_episode241.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4532_episode748.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6339_episode829.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8242_episode994.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7676_episode141.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9338_episode940.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2165_episode977.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2529_episode2131.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7524_episode2044.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4441_episode1528.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7338_episode165.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10246_episode1218.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3207_episode2425.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1988_episode1901.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3262_episode1456.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2743_episode1544.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9712_episode227.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4781_episode215.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1679_episode729.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2368_episode1519.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5668_episode225.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3018_episode1481.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8674_episode1421.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6841_episode586.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6378_episode2345.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2117_episode2007.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1283_episode305.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9385_episode33.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7309_episode863.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8964_episode1939.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5090_episode2090.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6663_episode1593.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6017_episode956.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/416_episode1183.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3510_episode2210.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4116_episode739.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8948_episode1346.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2045_episode1825.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3422_episode1940.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/103_episode749.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1664_episode571.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8563_episode113.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7404_episode1938.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10471_episode1721.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/583_episode2314.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9402_episode331.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8678_episode391.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9307_episode933.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9061_episode805.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7688_episode741.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4540_episode1401.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8591_episode930.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4329_episode1773.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1988_episode755.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5415_episode2439.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9720_episode1986.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3259_episode2447.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7200_episode2323.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7228_episode1688.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/973_episode1676.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6069_episode1167.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4311_episode175.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3703_episode712.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4994_episode1548.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3226_episode1215.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4573_episode1984.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4271_episode2195.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/470_episode2193.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/719_episode1989.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5607_episode612.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7848_episode1473.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10126_episode1476.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7920_episode2326.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6865_episode1323.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1897_episode734.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9449_episode2078.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/855_episode1820.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7241_episode2077.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1030_episode1219.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9896_episode1616.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8326_episode2371.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9274_episode2067.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9484_episode449.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2631_episode1651.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5669_episode526.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7542_episode2147.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9464_episode2065.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1849_episode367.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5205_episode405.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6738_episode1345.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8383_episode1760.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/387_episode147.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9002_episode1849.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/458_episode2050.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10255_episode948.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4282_episode1333.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/36_episode1620.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5778_episode1146.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4918_episode2369.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1530_episode408.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3883_episode1385.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9267_episode2412.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3611_episode433.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7416_episode2240.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/890_episode1761.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3006_episode1753.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10359_episode2254.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3655_episode1802.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7021_episode1843.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2775_episode1738.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6928_episode2032.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3034_episode349.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7338_episode272.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/23_episode1276.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1672_episode710.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4314_episode432.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3866_episode1524.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9402_episode543.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/903_episode2253.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2289_episode815.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3301_episode2342.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10220_episode1404.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/359_episode1075.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1298_episode1758.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/309_episode1522.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4803_episode1454.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4649_episode2241.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4591_episode2296.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9988_episode1899.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3008_episode1402.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2377_episode485.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4577_episode648.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1292_episode2446.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6018_episode1811.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/16_episode73.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9164_episode1851.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3269_episode2098.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8406_episode362.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9148_episode725.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8156_episode1364.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4113_episode951.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/258_episode2205.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4045_episode2132.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8221_episode1779.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9206_episode2375.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3659_episode2332.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4119_episode964.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1033_episode2105.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9260_episode1574.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2663_episode1467.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1517_episode448.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7473_episode1839.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9576_episode69.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9099_episode2402.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2690_episode1470.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5824_episode332.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/616_episode42.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9092_episode721.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5397_episode935.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4663_episode850.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6136_episode2046.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6098_episode637.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2208_episode79.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10370_episode563.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1375_episode1841.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4719_episode1949.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8304_episode510.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7239_episode1774.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3530_episode1174.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5405_episode1622.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/790_episode1063.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2439_episode301.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7967_episode1200.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9739_episode421.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1378_episode1862.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9673_episode1563.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1144_episode2406.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10339_episode1087.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4735_episode2442.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4043_episode1931.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5824_episode1305.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3788_episode1377.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8674_episode540.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1339_episode988.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5397_episode2245.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6836_episode1745.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4097_episode772.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6826_episode1810.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9151_episode2401.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10528_episode1869.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7974_episode1410.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6638_episode1034.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4113_episode469.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10246_episode2460.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3158_episode939.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3730_episode938.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2154_episode10.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2245_episode883.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10550_episode1607.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4690_episode1284.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1332_episode1497.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9640_episode480.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8163_episode1424.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4473_episode440.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/118_episode1145.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2743_episode1227.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2842_episode609.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7451_episode1143.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5635_episode31.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1439_episode500.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1988_episode664.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10246_episode320.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1615_episode1065.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10450_episode1502.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4695_episode336.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5877_episode1796.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6482_episode1185.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8801_episode160.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/348_episode750.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4212_episode1064.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/531_episode1562.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4476_episode122.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2815_episode476.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8236_episode839.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3700_episode860.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5931_episode1525.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2640_episode1110.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7105_episode1400.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/130_episode335.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/546_episode680.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3199_episode322.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8186_episode955.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3860_episode2088.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3339_episode436.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6695_episode1304.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2827_episode836.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5372_episode1724.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9129_episode453.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6809_episode2351.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1036_episode798.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3100_episode1106.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10405_episode1848.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2025_episode1757.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5680_episode1581.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/102_episode2376.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3351_episode2411.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/535_episode2429.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4113_episode2393.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4134_episode1196.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9953_episode1250.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7329_episode2230.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8489_episode300.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7105_episode916.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4137_episode944.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5198_episode1649.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8337_episode1942.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1125_episode126.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9779_episode268.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2381_episode1427.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7112_episode2010.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3217_episode723.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4871_episode910.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9971_episode781.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10455_episode1928.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2492_episode1003.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6428_episode1590.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2758_episode2396.csv
# ...
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3356_episode2231.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4221_episode208.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6138_episode1946.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3535_episode1393.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1159_episode602.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3541_episode1876.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1331_episode364.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1990_episode2202.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8432_episode770.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6948_episode1870.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4104_episode2462.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8627_episode730.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6148_episode1046.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9947_episode82.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1570_episode1337.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3866_episode1861.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2025_episode1165.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10346_episode2404.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7615_episode54.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7477_episode2115.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9859_episode1095.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5556_episode438.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4357_episode1598.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9463_episode991.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4261_episode99.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/116_episode662.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6950_episode2021.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10539_episode1668.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4664_episode199.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9300_episode1807.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6643_episode2216.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1956_episode389.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/327_episode1138.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/518_episode387.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7525_episode2059.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10510_episode2005.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7598_episode1251.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4113_episode70.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3961_episode75.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2181_episode2302.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1182_episode430.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1497_episode843.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5205_episode2405.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9663_episode529.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3249_episode557.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8284_episode1298.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10487_episode2177.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3820_episode1948.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9303_episode41.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4329_episode1566.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8252_episode2190.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10086_episode1108.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2069_episode2155.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3224_episode2317.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4104_episode1083.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6686_episode604.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7953_episode848.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5745_episode1965.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7686_episode1639.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10451_episode1814.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/785_episode2298.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1764_episode431.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2945_episode606.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6658_episode923.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3512_episode1386.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7548_episode379.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3765_episode941.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2649_episode2407.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4325_episode651.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1929_episode573.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/772_episode2138.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2246_episode2025.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6504_episode475.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2568_episode1992.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2783_episode443.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7111_episode1478.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5490_episode890.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8896_episode1532.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/518_episode1505.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7741_episode1754.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6568_episode2355.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7676_episode2414.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8674_episode1178.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/607_episode1353.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9674_episode1536.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/269_episode148.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1006_episode1162.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2605_episode1186.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5754_episode1120.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3100_episode1706.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8790_episode2392.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4273_episode1428.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4673_episode1039.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9874_episode36.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1139_episode2390.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5782_episode2394.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1488_episode2030.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7297_episode388.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2532_episode1712.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1491_episode2150.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1478_episode1262.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1006_episode2443.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/38_episode2123.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4577_episode488.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/813_episode1451.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8480_episode1844.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/4094_episode969.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1907_episode1209.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/34_episode1076.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/339_episode2051.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5781_episode429.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5723_episode177.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9481_episode1208.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10393_episode1220.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1533_episode1838.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7553_episode2259.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9357_episode1859.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5244_episode862.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10420_episode132.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/10080_episode2272.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/590_episode1786.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3819_episode2180.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6295_episode1957.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7821_episode2288.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6069_episode1803.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5194_episode121.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2330_episode1852.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/6866_episode55.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9385_episode2267.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/5487_episode1394.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/7330_episode1329.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/8703_episode306.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/9343_episode2312.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/1520_episode63.csv
# Deleted: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/3538_episode2184.csv
# ✅ 모든 .csv 파일 삭제 완료

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# ⚙️ 1️⃣ 설정
BASE_PATH = "/data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data"
TASK_NAME = "in-hospital-mortality"
SAVE_DIR = f"{BASE_PATH}/DATA_RAW/{TASK_NAME}"

# 폴더 구조 생성
os.makedirs(f"{SAVE_DIR}/train_note", exist_ok=True)
os.makedirs(f"{SAVE_DIR}/test_note", exist_ok=True)

# ⚙️ 2️⃣ final_dataset 불러오기 (이미 메모리에 있다면 이 부분 생략)
# final_dataset = pd.read_csv("/path/to/final_dataset.csv")

print(f"전체 데이터 수: {len(final_dataset):,}")
print(final_dataset.head(2))

# ⚙️ 3️⃣ (환자 단위 split)
patients = final_dataset["SUBJECT_ID"].unique()
train_pats, test_pats = train_test_split(patients, test_size=0.2, random_state=42)

# ⚙️ 4️⃣ train/test 분리
train_df = final_dataset[final_dataset["SUBJECT_ID"].isin(train_pats)].copy()
test_df  = final_dataset[final_dataset["SUBJECT_ID"].isin(test_pats)].copy()

print(f"train 환자 수: {len(train_pats)}, test 환자 수: {len(test_pats)}")
print(f"train 노트 수: {len(train_df):,}, test 노트 수: {len(test_df):,}")

# ⚙️ 5️⃣ HADM_ID 기준으로 episode 만들기
def make_episode_id(df):
    df = df.copy()
    df["episode"] = df.groupby("HADM_ID").ngroup().astype(str)
    return df

train_df = make_episode_id(train_df)
test_df = make_episode_id(test_df)

# ⚙️ 6️⃣ listfile.csv 생성
def make_listfile(df, split):
    list_records = []
    for (subj, hadm, epi), g in df.groupby(["SUBJECT_ID", "HADM_ID", "episode"]):
        label = int(g["label"].iloc[0])
        list_records.append({
            "patient": subj,
            "episode": f"episode{epi}",
            "y_true": label
        })
    listfile = pd.DataFrame(list_records)
    listfile.to_csv(f"{SAVE_DIR}/{split}_note/listfile.csv", index=False)
    print(f"{split}_note/listfile.csv 저장 완료 ({len(listfile)}행)")
    return listfile

train_list = make_listfile(train_df, "train")
test_list = make_listfile(test_df, "test")

# ⚙️ 7️⃣ episode별 파일 생성
def save_episode_csvs(df, split):
    base_path = f"{SAVE_DIR}/{split}_note"
    for (subj, hadm, epi), g in tqdm(df.groupby(["SUBJECT_ID", "HADM_ID", "episode"]),
                                     desc=f"Saving {split}_note files"):
        fname = f"{subj}_episode{epi}.csv"
        g_out = g[[
            "Hours", "HADM_ID", "SUBJECT_ID", "CATEGORY",
            "TEXT", "label"
        ]].copy()

        # note_id, SENT, WORD 등 downstream에서 요구되는 기본 컬럼 추가
        # (임시 더미로 note_id만 추가, 후속 단계에서 문장/단어 단위로 확장 가능)
        g_out["note_id"] = range(len(g_out))
        g_out["SENT"] = g_out["TEXT"].str[:50]  # 문장 단위 요약용 예시
        g_out["WORD"] = g_out["TEXT"].str.split().str[:10].apply(lambda x: " ".join(x))

        g_out.to_csv(f"{base_path}/{fname}", sep='\t', index=False)
    print(f"{split}_note 파일 저장 완료 ✅")

save_episode_csvs(train_df, "train")
save_episode_csvs(test_df, "test")

print("\n✅ TM-HGNN 인풋 폴더 구조 생성 완료!")
print(f"결과 폴더: {SAVE_DIR}")
# Out:
# 전체 데이터 수: 93,781
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID       CATEGORY  \
# 0           2   163353      243653  Nursing/other
# 1           2   163353      243653  Nursing/other
#
#                                                 TEXT           CHARTTIME  \
# 0  Neonatology Attending Triage Note Baby [**Name... 2138-07-17 22:51:00
# 1  Nursing Transfer note Pt admitted to NICU for ... 2138-07-17 23:08:00
#
#                INTIME     Hours  label  HOSPITAL_EXPIRE_FLAG
# 0 2138-07-17 21:20:07  1.514722      0                     0
# 1 2138-07-17 21:20:07  1.798056      0                     0
# train 환자 수: 7930, test 환자 수: 1983
# train 노트 수: 74,559, test 노트 수: 19,222
# train_note/listfile.csv 저장 완료 (9858행)
# test_note/listfile.csv 저장 완료 (2467행)
# Saving train_note files: 100%|██████████| 9858/9858 [00:29<00:00, 330.10it/s]
# train_note 파일 저장 완료 ✅
# Saving test_note files: 100%|██████████| 2467/2467 [00:07<00:00, 346.70it/s]
# test_note 파일 저장 완료 ✅
#
# ✅ TM-HGNN 인풋 폴더 구조 생성 완료!
# 결과 폴더: /data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality

# %%
import pandas as pd
import csv


df = pd.read_csv(
    "/data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2_episode1552.csv",
    sep='\t',
    engine='python')

print(df.columns)
print(df['TEXT'])
df.head()
# Out:
# Index(['Hours', 'HADM_ID', 'SUBJECT_ID', 'CATEGORY', 'TEXT', 'label',
#        'note_id', 'SENT', 'WORD'],
#       dtype='object')
# 0    Neonatology Attending Triage Note Baby [**Name...
# 1    Nursing Transfer note Pt admitted to NICU for ...
# Name: TEXT, dtype: object
#       Hours  HADM_ID  SUBJECT_ID       CATEGORY  \
# 0  1.514722   163353           2  Nursing/other
# 1  1.798056   163353           2  Nursing/other
#
#                                                 TEXT  label  note_id  \
# 0  Neonatology Attending Triage Note Baby [**Name...      0        0
# 1  Nursing Transfer note Pt admitted to NICU for ...      0        1
#
#                                                 SENT  \
# 0  Neonatology Attending Triage Note Baby [**Name...
# 1  Nursing Transfer note Pt admitted to NICU for ...
#
#                                                 WORD
# 0  Neonatology Attending Triage Note Baby [**Name...
# 1  Nursing Transfer note Pt admitted to NICU for ...

# %%
import pandas as pd
import csv


df = pd.read_csv(
    "/data1/project/juhyeon/MAGNET/OSS/TM-HGNN/data/DATA_RAW/in-hospital-mortality/test_note/2_episode1552.csv",
    sep='\t',
    engine='python',
    encoding='utf-8')

print(df.columns)
print(df['TEXT'])
df.head()
